# %%
import tensorflow as tf
import tensorflow.keras as keras
import pandas as pd
import numpy as np

# %%
imdb_reviews=pd.read_csv("/content/imdb_reviews.csv")
test_reviews=pd.read_csv("/content/test_reviews.csv")

# %%
imdb_reviews.head()
# Out:
#                                              Reviews Sentiment
# 0  <START this film was just brilliant casting lo...  positive
# 1  <START big hair big boobs bad music and a gian...  negative
# 2  <START this has to be one of the worst films o...  negative
# 3  <START the <UNK> <UNK> at storytelling the tra...  positive
# 4  <START worst mistake of my life br br i picked...  negative

# %%
word_index = pd.read_csv("/content/word_indexes.csv")

# %%
word_index.head()
# Out:
#      Words  Indexes
# 0  tsukino    52009
# 1  nunnery    52010
# 2    sonja    16819
# 3     vani    63954
# 4    woods     1411

# %%
word_index.head(n=10)
# Out:
#       Words  Indexes
# 0   tsukino    52009
# 1   nunnery    52010
# 2     sonja    16819
# 3      vani    63954
# 4     woods     1411
# 5   spiders    16118
# 6   hanging     2348
# 7     woody     2292
# 8  trawling    52011
# 9    hold's    52012

# %%
word_index=dict(zip(word_index.Words, word_index.Indexes))

# %%
word_index["<PAD>"]=0
word_index["<START>"]=1
word_index["<START"]=2
word_index["<UNK>"]=3
word_index["<UNUSED>"]=4

# %%
def review_encoder(text):
  arr = [word_index[word] for word in text]
  return arr

# %%
train_data, train_labels = imdb_reviews['Reviews'], imdb_reviews['Sentiment']
test_data, test_labels = test_reviews['Reviews'], imdb_reviews['Sentiment']

# %%
train_data = train_data.apply(lambda review:review.split())
test_data = test_data.apply(lambda review:review.split())

# %%
train_data = train_data.apply(review_encoder)
test_data = test_data.apply(review_encoder)

# %%
train_data[0]
# Out:
# [2,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  3,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  3,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  3,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  3,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  3,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  3,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
def encode_sentiments(sentiment):
   if sentiment=='positive':
    return 1
   else:
     return 0

train_labels=train_labels.apply(encode_sentiments)
test_labels=test_labels.apply(encode_sentiments)

# %%
train_data=keras.preprocessing.sequence.pad_sequences(train_data,value=word_index["<PAD>"],padding='post',maxlen=500)
test_data=keras.preprocessing.sequence.pad_sequences(test_data,value=word_index["<PAD>"],padding='post',maxlen=500)

# %%
model = keras.Sequential([keras.layers.Embedding(10000,16,input_length=500),
                         keras.layers.GlobalAveragePooling1D(),
                         keras.layers.Dense(16,activation='relu'),
                         keras.layers.Dense(1,activation='sigmoid')])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(train_data,train_labels,epochs=30,batch_size=512,validation_data=(test_data,test_labels))
# Out:
# Epoch 1/30
# 49/49 [==============================] - 2s 31ms/step - loss: 0.6137 - accuracy: 0.9994 - val_loss: 0.5205 - val_accuracy: 1.0000
# Epoch 2/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.4011 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 1.0000
# Epoch 3/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.1667 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 4/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 5/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 6/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 7/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 8/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 9/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 10/30
# 49/49 [==============================] - 1s 29ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 11/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 12/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 13/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 14/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 15/30
# 49/49 [==============================] - 1s 28ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 9.8660e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 49/49 [==============================] - 1s 28ms/step - loss: 9.2837e-04 - accuracy: 1.0000 - val_loss: 8.5140e-04 - val_accuracy: 1.0000
# Epoch 17/30
# 49/49 [==============================] - 1s 28ms/step - loss: 8.0499e-04 - accuracy: 1.0000 - val_loss: 7.4175e-04 - val_accuracy: 1.0000
# Epoch 18/30
# 49/49 [==============================] - 1s 28ms/step - loss: 7.0425e-04 - accuracy: 1.0000 - val_loss: 6.5157e-04 - val_accuracy: 1.0000
# Epoch 19/30
# 49/49 [==============================] - 1s 28ms/step - loss: 6.2090e-04 - accuracy: 1.0000 - val_loss: 5.7657e-04 - val_accuracy: 1.0000
# Epoch 20/30
# 49/49 [==============================] - 1s 28ms/step - loss: 5.5120e-04 - accuracy: 1.0000 - val_loss: 5.1345e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 49/49 [==============================] - 1s 28ms/step - loss: 4.9230e-04 - accuracy: 1.0000 - val_loss: 4.5986e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 49/49 [==============================] - 1s 28ms/step - loss: 4.4209e-04 - accuracy: 1.0000 - val_loss: 4.1399e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 49/49 [==============================] - 1s 28ms/step - loss: 3.9894e-04 - accuracy: 1.0000 - val_loss: 3.7444e-04 - val_accuracy: 1.0000
# Epoch 24/30
# 49/49 [==============================] - 1s 28ms/step - loss: 3.6159e-04 - accuracy: 1.0000 - val_loss: 3.4010e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 49/49 [==============================] - 1s 28ms/step - loss: 3.2906e-04 - accuracy: 1.0000 - val_loss: 3.1007e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 49/49 [==============================] - 1s 28ms/step - loss: 3.0055e-04 - accuracy: 1.0000 - val_loss: 2.8368e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 49/49 [==============================] - 1s 28ms/step - loss: 2.7543e-04 - accuracy: 1.0000 - val_loss: 2.6036e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 49/49 [==============================] - 1s 28ms/step - loss: 2.5318e-04 - accuracy: 1.0000 - val_loss: 2.3966e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 49/49 [==============================] - 1s 28ms/step - loss: 2.3338e-04 - accuracy: 1.0000 - val_loss: 2.2122e-04 - val_accuracy: 1.0000
# Epoch 30/30
#  1/49 [..............................] - ETA: 1s - loss: 2.2492e-04 - accuracy: 1.0000

# %%
loss,accuracy=model.evaluate(test_data,test_labels)
# Out:
# 782/782 [==============================] - 1s 2ms/step - loss: 2.0471e-04 - accuracy: 1.0000

# %%
test_reviews.head()
# Out:
#                                              Reviews Sentiment
# 0  <START please give this one a miss br br <UNK>...  negative
# 1  <START this film requires a lot of patience be...  positive
# 2  <START many animation buffs consider <UNK> <UN...  positive
# 3  <START i generally love this type of movie how...  negative
# 4  <START like some other people wrote i'm a die ...  positive

# %%
index=np.random.randint(1,1000)

# %%
user_review=test_reviews.loc[index]
print(user_review)
# Out:
# Reviews      <START just can't watch this bit too many time...
# Sentiment                                             positive
# Name: 62, dtype: object

# %%
user_review=test_data[index]
user_review=np.array([user_review]) 
if (model.predict(user_review) > 0.5).astype("int"):
  print("positive sentiment")
else:
  print("negative sentiment")
# Out:
# negative sentiment
